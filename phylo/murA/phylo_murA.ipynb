# %%
from Bio import Phylo
tree = Phylo.read("clustalw_murA_comp.dnd", "newick")
#print (tree)
Phylo.draw_ascii(tree)
#tree.ladderize()
#Phylo.draw(tree)
# Out:
#  , WP_003406845.1
#  |
#  |  , QKI29380.1
#  | _|
#  || | CLR28030.1
#  ||
#  || WP_181903553.1
#  ||
#  ||_ SGD80192.1
#  |
#  |__ WP_057119784.1
#  |
#  |__ WP_057383146.1
#  |
#  |__ WP_031682655.1
#  |
#  | _ WP_055371176.1
#  ||
#  ||_ WP_019250103.1
#  |
#  |__ WP_031666215.1
#  |
#  | _ WP_057361817.1
#  ||
#  ||_ WP_064319954.1
#  |
#  |__ WP_052657353.1
#  |
#  |__ WP_057371844.1
#  |
#  |__ WP_072534188.1
#  |
#  |  , WP_193566711.1
#  |__|
#  |  |__ WP_214652684.1
#  |
#  |__ WP_055372908.1
#  |
#  |__ WP_055366993.1
#  |
#  |__ WP_057330567.1
#  |
#  |__ WP_055376052.1
#  |
#  |__ WP_031701333.1
#  |
#  |__ WP_023349499.1
#  |
#  |__ WP_070893861.1
#  |
#  |__ WP_057364291.1
#  |
#  |__ WP_057138846.1
#  |
#  |  , WP_055352665.1
#  |__|
#  |  |_____ WP_057340356.1
#  |
#  |__ CMB68856.1
#  |
#  |  , WP_057351261.1
#  | _|
#  ,| |________ WP_055386509.1
#  ||
#  ||_ WP_055374653.1
#  |
#  |  , WP_057343514.1
#  |  |
#  |__|__ WP_055368665.1
#  |  |
# ...
